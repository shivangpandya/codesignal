# %%
#Program for array rotation
arr = [1,2,3,4,5,6,7]
d=2
n = len(arr)
def leftRotatebyOne(arr,n):
    temp = arr[0]
    for i in range(n-1):
        arr[i] = arr[i+1]
    arr[i+1] = temp
    
def leftRotate(arr,d,n):
    for i in range(d):
        leftRotatebyOne(arr,n)
    return arr

leftRotate(arr,d,n)
# Out:
# [3, 4, 5, 6, 7, 1, 2]

# %%
using namespace std; 
  
// Function that checks if sum  
// is prime or not 
bool isPrimeString(string str) 
{ 
    int len = str.length(), n = 0; 
    for (int i = 0; i < len; i++) 
        n += (int)str[i]; 
  
    // Corner cases 
    if (n <= 1) 
        return false; 
    if (n <= 3) 
        return true; 
  
    // This is checked so that we can skip 
    // middle five numbers in below loop 
    if (n % 2 == 0 || n % 3 == 0) 
        return false; 
  
    for (int i = 5; i * i <= n; i = i + 6) 
        if (n % i == 0 || n % (i + 2) == 0) 
            return false; 
  
    return true; 
} 
  
// Driver code 
int main() 
{ 
    string str = "geekRam"; 
    if (isPrimeString(str)) 
        cout << "Yes" << endl; 
    else
        cout << "No" << endl; 
}

# %%
capacity =2
maxweight = 180

def trip(cap, max_weight,a):
    for i in range(cap)

# %%
#Cylclically rotate elements by one
a = [1,2,3,4,5]
n = len(a)
def rotateCylcic(a,n):
    temp = a[n-1]
    for i in range(n-1,0,-1):
        a[i] = a[i-1]
    a[0] = temp
    return a
rotateCylcic(a,n)
# Out:
# [5, 1, 2, 3, 4]

# %%
#Selection sort
A = [64, 25, 12, 22, 11] 
n = len(A)
def Selctionsort(A,n):
    for i in range(len(A)):
        min  = i
        for j in range(i+1,len(A)):
            if  A[min] > A[j]:
                min = j
        A[i],A[min] = A[min], A[i] 
    return A
    
Selctionsort(A,n)
# Out:
# [11, 12, 22, 25, 64]

# %%
#Bubble sort
A = [64, 25, 12, 22, 11] 
n = len(A)
def BubbleSort(A,n):
    for i in range (n):
        for j in range(0, n-i-1):
            if(A[j]>A[i]):
                A[j], A[j+1] = A[j+1], A[j]
    return A

BubbleSort(A,n)
# Out:
# [12, 64, 25, 22, 11]

# %%
#Insertion Sort 
arr = [64, 25, 12, 22, 11] 
n = len(A)
def insertionSort(arr):
    for i in range(n):
        key = A[i]
        j = i-1
        while j>=0 and key< arr[j]:
            arr[j+1] = arr[j]
            j = j-1
        arr[j+1] = key
    return arr
insertionSort(arr)
# Out:
# [11, 12, 22, 25, 64]

# %%
#Find length of linked list
class Node:
    
    def __init__(self,data):
        self.data = data
        self.next = None

class LinkedList:
    
#Function to initialize head
    def __init__(self):
        self.head = None
        
    #Function to insert new node at beginning
    def push(self,new_data):
        
        # Allocate the Node & Put in the data 
        new_node = Node(new_data) 
  
        # Make next of new Node as head 
        new_node.next = self.head 
  
        # 4. Move the head to point to new Node
        self.head = new_node
    
    def LinkedListlength(self):
        temp = self.head
        count = 0
        while(temp):
            count+=1
            temp = temp.next
        return count
    
    #Recursive Linked List count 
    def Recursivecount(self, node): 
        if (not node): # Base case 
            return 0
        else: 
            return 1 + self.getCountRec(node.next) 
  
    # A wrapper over getCountRec() 
    def getCount(self): 
        return self.getCountRec(self.head) 

    def deleteNode(self,key):
        
        #Store head node
        temp = self.head
        
        #If head node itself contains to be deleted
        if(temp is not None):
            if(temp.data == key):
                self.head = temp.next
                temp = None
                return
        
        #Search for key to be deleted,keep track of the previous node as we need to change 'prev.next'
        while(temp is not None):
            if temp.data == key:
                break
            prev = temp
            temp = temp.next
            
        # if key was not present in linked list 
        if(temp == None): 
            return 
  
        # Unlink the node from linked list 
        prev.next = temp.next 
        temp = None 
        
#This Function checks whether the value x present in the linked list  
    def search(self, x): 
  
        # Initialize current to head 
        current = self.head 
  
        # loop till current not equal to None 
        while current != None: 
            if current.data == x: 
                return True # data found 
              
            current = current.next
          
        return False # Data Not found 
    
#Print nth from last
    def PrintfromLast(self,n):
        temp = self.head
        length = 0
        while(temp):
            for i in range(0,n-length):
                temp = temp.next
            print(temp.data)


#Count Occurences of a given element in linked list        
    def count(self, search_for): 
        current = self.head 
        count = 0
        while(current is not None): 
            if current.data == search_for: 
                count += 1
            current = current.next
        return count 
    
# Removes duplicates from a sorted list          
    def removeDuplicates(self): 
        temp = self.head 
        if temp is None: 
            return
        while temp.next is not None: 
            if temp.data == temp.next.data: 
                new = temp.next.next
                temp.next = None
                temp.next = new 
            else: 
                temp = temp.next
        return self.head 

# Function to reverse the linked list 
    def reverse(self): 
        prev = None
        current = self.head 
        while(current is not None): 
            next = current.next
            current.next = prev 
            prev = current 
            current = next
        self.head = prev 
  
            

#Driver code 
l = LinkedList()
l.push(1)
l.push(4)
l.push(8)
l.push(43)
l.push(34)


l.LinkedListlength()
# Out:
# 5

# %%
#Circular linked list operations

# Python program to demonstrate  
# circular linked list traversal  
  
# Structure for a Node 
class Node: 
    def __init__(self,data):
        self.data = data
        self.next = None

class Doublylinkedlist:
    def __init__(self, next = None , prev = None , data = None):
        self.next = next
        self.prev = prev
        self.data = data
        
    #Insert node at beginning of linked list
    def push(self, new_data):
        
        #Initialize node
        new_node = Node(data = new_data)
        
        #Make next of new node as head and prev as NULL
        new_node.next = self.head
        new_node.prev = None
        
        #Change prev of head to new node
        if(self.head is not None):
            self.head.prev = new_node
        
        #Make new node the head
        self.head = new_node

# %%
#Tree
class Node: 
    def __init__(self,key): 
        self.left = None
        self.right = None
        self.key = data
        
def inorder(temp):
    if(not temp):
        return
    
    inorder(temp.left)
    print(temp.data, end = " ")
    inorder(temp.right)
    
def insert(temp, key):
    q= []
    q.append(temp)
    
    while(len(q)):
        q = temp[0]
        q.pop(0)
        
        #Incase temp does not contain left subtree
        if(not temp.left):
            temp.left = Node(key)
            break
        else:
            q.append(temp.left)
            
        if(not temp.right):
            temp.right = Node(key)
            break
        else:
            q.append(temp.right)

def deleteDeepest(root,d_node): 
    q = [] 
    q.append(root) 
    while(len(q)): 
        temp = q.pop(0) 
        if temp is d_node: 
            temp = None
            return
        if temp.right: 
            if temp.right is d_node: 
                temp.right = None
                return
            else: 
                q.append(temp.right) 
        if temp.left: 
            if temp.left is d_node: 
                temp.left = None
                return
            else: 
                q.append(temp.left)
        

# Driver code  
if __name__ == '__main__': 
    root = newNode(10)  
    root.left = newNode(11)  
    root.left.left = newNode(7)  
    root.right = newNode(9)  
    root.right.left = newNode(15)  
    root.right.right = newNode(8)

# %%
def nearest_prime(n):
    incr = -1
    multiplier = -1
    count = 1
    while True:
        if prime(n):
            return n
        else:
            n = n + incr
            multiplier = multiplier * -1
            count = count + 1
            incr = multiplier * count
            return n
            
nearest_prime(13)

# %% [markdown]
# # Happy Colony(Salesforce SDE)
#
# You are an administrator of a society "Happy Colony".
# You have a mxn matrix and are given the job of assigning houses to society members,
# where each cell repressents a house.Each member is of two kinds : either an Introvert
# or an Extrovert.
#
# Introverts do not like having neighbors. Their happiness zaps down by 30 points for
# every wall that they share with someone (could be either introvert or extrovert).
# Extroverts love having neighbors. Their hapiness boosts by 20 points for every wall they
# share with someone(introvert or extrovert).
# There can be at most 4 neighbors( corresponding to the 4 sides of cells or houses ).
#
# Extroverts start with a happiness point of 40, while introverts start with happiness points of 120.
#
# Given values of m,n and the number of introverts and extroverts, find the maximum happiness points you can gain.
#
# Constraints
# 1 <= m,n <= 10 and 0 <= I,E <= 10
#
# Sample Input
# Test 1: m = 1, n=1,I =1, E=0.
# Test 2 : m=2, n=3, I=1, E=2.
#
# Sample Output
# Test 1 : 120
# Test 2 : 240
#
# For the second case, we can give the introvert 1 corner and keep the extroverts together.
# The points will be 120(base introvert) + 2x40 + 2x20 = 240'''
